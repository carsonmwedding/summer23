# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# %%
df = pd.read_csv('test_folder/cleaned/merged_003_07062023_134419.csv')

# %%
df = df [df['basal delivered (units)'].notnull()]

# %%
s = df['Glucose Value (mg/dL)']
type(s)
s.autocorr()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 5195    126.0
# 5196    129.0
# 5197    134.0
# 5198    137.0
# 5199    139.0
#         ...
# 8202    125.0
# 8203    137.0
# 8204    145.0
# 8205    150.0
# 8206    143.0
# Name: Glucose Value (mg/dL), Length: 2997, dtype: float64

# %%
s_arr = pd.Series(s).array

# %%
x = pd.plotting.autocorrelation_plot(s_arr[:134])
 
# plotting the Curve
x.plot()
 
# Display
plt.show()

# %%
pd.plotting.autocorrelation_plot(s[:134]);

# %%
plot_acf(s[:134])
